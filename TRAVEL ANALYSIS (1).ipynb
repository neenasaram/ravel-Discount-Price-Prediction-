# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\saram\Downloads\Tour.csv")
df
# Out:
#                                                    name  rating  \
# 0                 Coorg Package For 2 Nights And 3 Days       3
# 1     Best 4N 5D Andaman Sightseeing Tour Package Fo...       3
# 2       Mesmerising Manali Trip Package From Chandigarh       3
# 3     Top Family Holiday Packages in Goa for an Idea...       3
# 4     Most Affordable 1 Night 2 Days Uttarakhand Tou...       2
# ...                                                 ...     ...
# 1370  Thrilling Gangtok, Pelling, Darjeeling Family ...       2
# 1371                                  Stunning Leh Tour       3
# 1372  Golden Triangle Tour With Rajasthan and Madhya...       3
# 1373                          A Pleasant Tour In Munnar       3
# 1374                   A Tour Amid Nature In Kodaikanal       3
#
#                                                  places  no_of_places_visited  \
# 0                                            Coorg (3D)                     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  1375 non-null   object
#  1   rating                1375 non-null   int64
#  2   places                1375 non-null   object
#  3   no_of_places_visited  1375 non-null   int64
#  4   adventure             1375 non-null   object
#  5   nature                1375 non-null   object
#  6   hill_station          1375 non-null   object
#  7   religious             1375 non-null   object
#  8   water_activites       1375 non-null   object
#  9   days                  1375 non-null   int64
#  10  nights                1375 non-null   int64
#  11  discount_percentage   1375 non-null   int64
#  12  original_price        1375 non-null   object
#  13  discount_price        1375 non-null   object
# dtypes: int64(5), object(9)
# memory usage: 150.5+ KB

# %%
df.columns
# Out:
# Index(['name', 'rating', 'places', 'no_of_places_visited', 'adventure',
#        'nature', 'hill_station', 'religious', 'water_activites', 'days',
#        'nights', 'discount_percentage', 'original_price', 'discount_price'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name                    0
# rating                  0
# places                  0
# no_of_places_visited    0
# adventure               0
# nature                  0
# hill_station            0
# religious               0
# water_activites         0
# days                    0
# nights                  0
# discount_percentage     0
# original_price          0
# discount_price          0
# dtype: int64

# %%
# Converting the datatypes
df['original_price'] = df['original_price'].str.replace(',','')
df['discount_price'] = df['discount_price'].str.replace(',','')

df['original_price'] = df['original_price'].astype('int64')
df['discount_price'] = df['discount_price'].astype('int64')

# %%
df.to_csv("Tour.csv", index=False)

# %%
#df.shape
#df.drop(columns=["name","nights"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  1375 non-null   object
#  1   rating                1375 non-null   int64
#  2   places                1375 non-null   object
#  3   no_of_places_visited  1375 non-null   int64
#  4   adventure             1375 non-null   object
#  5   nature                1375 non-null   object
#  6   hill_station          1375 non-null   object
#  7   religious             1375 non-null   object
#  8   water_activites       1375 non-null   object
#  9   days                  1375 non-null   int64
#  10  nights                1375 non-null   int64
#  11  discount_percentage   1375 non-null   int64
#  12  original_price        1375 non-null   int64
#  13  discount_price        1375 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 150.5+ KB

# %% [markdown]
# # Univariate Analysis

# %%
def numerical(df,col):
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    min_1 = df[col].min()
    max_1 = df[col].max()
    range_1 = df[col].max() - df[col].min()
    var = df[col].var()
    std = df[col].std()
    coeffvar = (df[col].std() / df[col].mean()) * 100
    iqr = df[col].quantile(0.75) - df[col].quantile(0.25)

    print("Mean : ",mean)
    print("Median : ",median)
    print("Mode : ",mode)
    print("Minimum : ",min_1)
    print("Maximum : ",max_1)
    print("Range : ",range_1)
    print("Variance : ",var)
    print("Standard Deviation : ",std)
    print("Coefficient of Variance : ",coeffvar)
    print("IQR : ",iqr)

# %%
numerical(df,"discount_percentage")
# Out:
# Mean :  9.635636363636364
# Median :  9.0
# Mode :  9
# Minimum :  1
# Maximum :  36
# Range :  35
# Variance :  11.627695646420733
# Standard Deviation :  3.409940710103437
# Coefficient of Variance :  35.3888480367743
# IQR :  1.0

# %%
df['discount_percentage'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
numerical(df,"discount_price")
# Out:
# Mean :  19088.209454545453
# Median :  15000.0
# Mode :  11500
# Minimum :  2800
# Maximum :  74089
# Range :  71289
# Variance :  173309515.36366504
# Standard Deviation :  13164.707188679324
# Coefficient of Variance :  68.96774273159721
# IQR :  13713.0

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='discount_price',color='yellowgreen')
plt.title('Plot for Discount Price')
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.show()

# %%
numerical(df,"original_price")
# Out:
# Mean :  21076.088
# Median :  16667.0
# Mode :  12637
# Minimum :  3333
# Maximum :  80136
# Range :  76803
# Variance :  206386147.41947025
# Standard Deviation :  14366.145879096113
# Coefficient of Variance :  68.1632467993876
# IQR :  14957.0

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='original_price', kde=True,color='darkslateblue')
plt.title('Plot for Original Price')
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.show()

# %%
def categorical(df,col):
    unique = df[col].unique()
    nunique = df[col].nunique()
    count = df[col].value_counts()

    print("Unique Values : ",unique)
    print()
    print("Number of Unique Values : ",nunique)
    print()
    print("Count : ",count)

# %%
categorical(df,'adventure')
# Out:
# Unique Values :  ['Yes' 'No']
#
# Number of Unique Values :  2
#
# Count :  adventure
# Yes    1044
# No      331
# Name: count, dtype: int64

# %%
plt.title("Adventure")
df['adventure'].value_counts().plot(kind='pie', autopct='%.2f',colors=['deeppink','hotpink'])
# Out:
# <Axes: title={'center': 'Adventure'}, ylabel='count'>

# %%
categorical(df,'rating')
# Out:
# Unique Values :  [3 2 4 5]
#
# Number of Unique Values :  4
#
# Count :  rating
# 3    951
# 2    253
# 4    138
# 5     33
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='pie', autopct='%.2f', explode=[0.1,0,0,0],colors=['darkred','r','salmon','tomato'])
plt.title('Plot for rating')
plt.xticks(rotation=45)
plt.show()

# %%
categorical(df,'nature')
# Out:
# Unique Values :  ['Yes' 'No']
#
# Number of Unique Values :  2
#
# Count :  nature
# Yes    1150
# No      225
# Name: count, dtype: int64

# %%
plt.title("Nature")
df['nature'].value_counts().plot(kind='pie', autopct='%.2f',colors=['yellowgreen','yellow'])
# Out:
# <Axes: title={'center': 'Nature'}, ylabel='count'>

# %%
categorical(df,'hill_station')
# Out:
# Unique Values :  ['No' 'Yes']
#
# Number of Unique Values :  2
#
# Count :  hill_station
# No     1346
# Yes      29
# Name: count, dtype: int64

# %%
plt.title("Hill Station")
df['hill_station'].value_counts().plot(kind='pie', autopct='%.2f',colors=['forestgreen','r'])
# Out:
# <Axes: title={'center': 'Hill Station'}, ylabel='count'>

# %%
categorical(df,'religious')
# Out:
# Unique Values :  ['Yes' 'No']
#
# Number of Unique Values :  2
#
# Count :  religious
# No     1001
# Yes     374
# Name: count, dtype: int64

# %%
plt.title("Religious")
df['religious'].value_counts().plot(kind='pie', autopct='%.2f',colors=['r','y'])
# Out:
# <Axes: title={'center': 'Religious'}, ylabel='count'>

# %%
categorical(df,'water_activites')
# Out:
# Unique Values :  ['No' 'Yes']
#
# Number of Unique Values :  2
#
# Count :  water_activites
# No     1140
# Yes     235
# Name: count, dtype: int64

# %%
plt.title("Water Activities")
df['water_activites'].value_counts().plot(kind='pie', autopct='%.2f',colors=['dodgerblue','lightblue'])
# Out:
# <Axes: title={'center': 'Water Activities'}, ylabel='count'>

# %%
plt.figure(figsize=(7,5))
df['places'].value_counts().nlargest(7).plot(kind='bar',color='darkviolet')
plt.title('Plot for Top 7 Places')
plt.grid(axis='y')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# + The most popular travel destinations based on the dataset.
# + The relative frequency of each place (higher bar = more tours).
# + Helps in identifying top tourist spots for better business decisions.

# %%
categorical(df,'no_of_places_visited')
# Out:
# Unique Values :  [ 1  2  3  4  5  8  7  6 13]
#
# Number of Unique Values :  9
#
# Count :  no_of_places_visited
# 1     816
# 2     186
# 3     171
# 4      97
# 5      72
# 7      11
# 13     10
# 6       7
# 8       5
# Name: count, dtype: int64

# %%
df['no_of_places_visited'].value_counts().plot(kind='pie', autopct='%.2f', explode=[0.1,0.1,0.1,0,0,0,0,0,0])
plt.title('Chart for Number of places visited')
plt.xticks(rotation=45)
plt.show()

# %%
df['nights'].value_counts().plot(kind='pie', autopct='%.2f')
plt.title('Chart for Number of places visited')
plt.xticks(rotation=45)
plt.show()

# %%
categorical(df,'days')
# Out:
# Unique Values :  [ 3  5  2  6  7  4  9  8 10 11 18]
#
# Number of Unique Values :  11
#
# Count :  days
# 3     451
# 4     318
# 5     148
# 2     126
# 6     106
# 7      93
# 8      53
# 9      40
# 10     18
# 11     12
# 18     10
# Name: count, dtype: int64

# %%
df['days'].value_counts().plot(kind='bar',color='r')
plt.title('Plot for Days')
plt.grid(axis='y')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(data=df, x='original_price', y='discount_price',color='r')
plt.title('Correlation between Original Price and Discount Price')
plt.grid(axis='y')
plt.xticks(rotation=0)
plt.show()

# %%
f = df[['original_price','discount_price']].corr()

# %%
plt.figure(figsize=(5,3))
sns.heatmap(data=f, cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.3, linecolor='white', cbar_kws={"shrink": 0.8})
plt.title('Correlation Heatmap')
plt.xticks(rotation=0)
plt.show()

# %%
# analysis on rating
plt.figure(figsize=(5,3))
top_10 = df.groupby("places")["rating"].sum().nlargest(10).reset_index()
sns.barplot(data=top_10, x="rating", y="places",color='magenta')
# Out:
# <Axes: xlabel='rating', ylabel='places'>

# %%
sns.barplot(data=df, x="rating", y="discount_percentage",palette='cool')
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_14020\857383235.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="rating", y="discount_percentage",palette='cool')
# <Axes: xlabel='rating', ylabel='discount_percentage'>

# %%
#analysis on places
plt.figure(figsize=(5, 4))  
sns.barplot(data=place_counts, x="count", y="places", color='r')
plt.xlabel("Number of Mentions")  
plt.ylabel("Adventure Places")  
plt.title("Top 10 Adventure Places")  
plt.show()

# %% [markdown]
# The x-axis represents the "count" of each place, which is the number of times a particular place appears in the dataset where "adventure" == "Yes".

# %%
plt.figure(figsize=(5, 4))  

place_counts = df[df["nature"] == "Yes"]["places"].value_counts().nlargest(10).reset_index()
place_counts.columns = ["places", "count"]

sns.barplot(data=place_counts, x="count", y="places", color='forestgreen')

plt.xlabel("Number of Mentions")
plt.ylabel("Nature Places")
plt.title("Top 10 Nature Places")
plt.show()

# %%
plt.figure(figsize=(5,4))  

place_counts = df[df["religious"] == "Yes"]["places"].value_counts().nlargest(10).reset_index()
place_counts.columns = ["places", "count"]

sns.barplot(data=place_counts, x="count", y="places", color='yellowgreen')

plt.xlabel("Number of Mentions")
plt.ylabel("Religious Places")
plt.title("Top 10 Religious Places")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'hill_station' values are properly formatted
df["hill_station"] = df["hill_station"].astype(str).str.strip().str.lower()

# Count available hill stations
num_hill_stations = df[df["hill_station"] == "yes"]["places"].nunique()
print(f"Total unique hill stations: {num_hill_stations}")

# Get place counts (without restricting to 10)
place_counts = df[df["hill_station"] == "yes"]["places"].value_counts().reset_index()
place_counts.columns = ["places", "count"]

# Use min(10, num_hill_stations) to avoid errors if less than 10 exist
place_counts = place_counts.nlargest(min(10, num_hill_stations), "count")

# Plot
plt.figure(figsize=(4, 3))
sns.barplot(data=place_counts, x="count", y="places", color="green")

plt.xlabel("Number of Mentions")
plt.ylabel("Hill Stations")
plt.title(f"Top {min(10, num_hill_stations)} Hill Stations")
plt.show()
# Out:
# Total unique hill stations: 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'water_activites' values are properly formatted
df["water_activites"] = df["water_activites"].astype(str).str.strip().str.lower()

# Count unique places
num_water_places = df[df["water_activites"] == "yes"]["places"].nunique()
print(f"Total unique water activity places: {num_water_places}")

# Get place counts (without restricting to 10 initially)
place_counts = df[df["water_activites"] == "yes"]["places"].value_counts().reset_index()
place_counts.columns = ["places", "count"]

# Use min(10, num_water_places) to avoid errors if fewer than 10 exist
place_counts = place_counts.nlargest(min(10, num_water_places), "count")

# Plot
plt.figure(figsize=(3, 2))
sns.barplot(data=place_counts, x="count", y="places", color="orangered")

plt.xlabel("Number of Mentions")
plt.ylabel("Water Activity Places")
plt.title(f"Top {min(10, num_water_places)} Places for Water Activities")
plt.show()
# Out:
# Total unique water activity places: 27

# %%
top_10 = df.groupby("places")["days"].sum().nlargest(10).reset_index()
sns.barplot(data=top_10, x="days", y="places",color='orange')
# Out:
# <Axes: xlabel='days', ylabel='places'>

# %%
# Reduce figure size for better compactness
plt.figure(figsize=(5, 4))  # Smaller figure size

# Plot the bar graph
sns.barplot(x="places", y="discount_price", data=top_10, palette="Blues_r")

# Add labels and title
plt.xlabel("Places", fontsize=12)
plt.ylabel("Discount Price (₹)", fontsize=12)
plt.title("Top 10 Places with Highest Discount Price", fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=60, ha='right')

# Show the grid and display the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_5792\2951201507.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="places", y="discount_price", data=top_10, palette="Blues_r")

# %% [markdown]
# # Multivariate analysis

# %%
# greater than 4

# %%
# Filter data for ratings >= 4
filtered_df = df[df["rating"] >= 4]

# Count of places based on days
days_count = filtered_df["days"].value_counts().sort_index()

# Plot the bar graph
plt.figure(figsize=(7, 5))
sns.barplot(x=days_count.index, y=days_count.values, palette="Reds_r")

# Add labels and title
plt.xlabel("Number of Days", fontsize=12)
plt.ylabel("Count of Places", fontsize=12)
plt.title("Count of Places with Different Days (Rating >= 4)", fontsize=14)

# Show the grid and display the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_5792\2049433674.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=days_count.index, y=days_count.values, palette="Reds_r")

# %%
# Filter data for ratings >= 4
filtered_df = df[df["rating"] <= 4]

# Count of places based on days
days_count = filtered_df["days"].value_counts().sort_index()

# Plot the bar graph
plt.figure(figsize=(7, 5))
sns.barplot(x=days_count.index, y=days_count.values, palette="Greens_r")

# Add labels and title
plt.xlabel("Number of Days", fontsize=12)
plt.ylabel("Count of Places", fontsize=12)
plt.title("Count of Places with Different Days (Rating <= 4)", fontsize=14)

# Show the grid and display the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_5792\3810547470.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=days_count.index, y=days_count.values, palette="Greens_r")

# %%
# Filter data for rating >= 3 and nature = "Yes"
filtered_df = df[(df["rating"] >= 3) & (df["nature"] == "Yes")]

# Count of places based on days
days_count = filtered_df["days"].value_counts().sort_index()

# Plot the bar graph
plt.figure(figsize=(7, 5))
sns.barplot(x=days_count.index, y=days_count.values, palette="magma")

# Add labels and title
plt.xlabel("Number of Days", fontsize=12)
plt.ylabel("Count of Places", fontsize=12)
plt.title("Count of Places with Different Days (Rating ≥ 3 & Nature = Yes)", fontsize=14)

# Show the grid and display the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_5792\3705916393.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=days_count.index, y=days_count.values, palette="magma")

# %%
# Filter data for rating >= 3 and nature = "Yes"
filtered_df = df[(df["rating"] >= 3) & (df["religious"] == "Yes")]

# Count of places based on days
days_count = filtered_df["days"].value_counts().sort_index()

# Plot the bar graph
plt.figure(figsize=(7, 5))
sns.barplot(x=days_count.index, y=days_count.values, palette="viridis")

# Add labels and title
plt.xlabel("Number of Days", fontsize=12)
plt.ylabel("Count of Places", fontsize=12)
plt.title("Count of Places with Different Days (Rating ≥ 3 & Nature = Yes)", fontsize=14)

# Show the grid and display the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\saram\AppData\Local\Temp\ipykernel_5792\2720446403.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=days_count.index, y=days_count.values, palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data for rating >= 4
greater_than_4 = df[df["rating"] >= 4]

# Find the top 5 most frequent places
top_5_places = greater_than_4["places"].value_counts().nlargest(5).index

# Filter the DataFrame to only include rows with the top 5 places
top_5_places_df = greater_than_4[greater_than_4["places"].isin(top_5_places)]

# Filter data for hill station activities
hill_station_df = top_5_places_df[top_5_places_df["hill_station"] == "Yes"]

# Check if the filtered data is empty
if hill_station_df.empty:
    print("No data available for hill station with rating >= 4")
else:
    # Check for missing values
    print(hill_station_df[['days', 'places']].isnull().sum())

    # Plot: Count of Places with Different Days (Days as hue)
    sns.countplot(data=hill_station_df, x="days", hue="places", palette="Set2")

    # Improve readability and title
    plt.title("Count of Places with Different Days (Rating >= 4 and Hill Station = Yes)")
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.show()
# Out:
# No data available for hill station with rating >= 4

# %%
# Filter the data for rating >= 4
greater_than_4 = df[df["rating"] >= 4]

# Find the top 5 most frequent places
top_5_places = greater_than_4["places"].value_counts().nlargest(5).index

# Filter the DataFrame to only include rows with the top 5 places
top_5_places_df = greater_than_4[greater_than_4["places"].isin(top_5_places)]

# Filter data for adventure activities
water_activites_df = top_5_places_df[top_5_places_df["water_activites"] == "Yes"]

# Plot: Count of Places with Different Days (Days as hue)
sns.countplot(data=water_activites_df, x="days", hue="places")

# Improve readability and title
plt.title("Count of Places with Different Days (Rating >= 4 and water_activites = Yes)")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# less than 4

# %%
# Filter the data for rating < 4
less_than_4 = df[df["rating"] < 4]

# Find the top 5 most frequent places
top_5_places = less_than_4["places"].value_counts().nlargest(5).index

# Filter the DataFrame to only include rows with the top 5 places
top_5_places_df = less_than_4[less_than_4["places"].isin(top_5_places)]

# Plot: Count of Places with Different Days (Days as hue)
sns.countplot(data=top_5_places_df, x="rating", hue="places")
plt.title("Count of Places with rating less than 4")
plt.xticks(rotation=45)
plt.show()

# %%
top_5_places_df[['rating','places']].value_counts()
# Out:
# rating  places
# 3       Dharamshala (4D)    26
#         Shillong (3D)       24
#         Goa (3D)            23
#         Goa (4D)            23
# 2       Gangtok (3D)        20
#         Goa (4D)             9
#         Dharamshala (4D)     6
# Name: count, dtype: int64

# %%
df[df['rating'] < 4]['rating'].value_counts()
# Out:
# rating
# 3    951
# 2    253
# Name: count, dtype: int64

# %%
less_than_4[less_than_4["rating"]==4]
# Out:
# Empty DataFrame
# Columns: [name, rating, places, no_of_places_visited, adventure, nature, hill_station, religious, water_activites, days, nights, discount_percentage, original_price, discount_price]
# Index: []

# %%
# Filter the data for rating >= 4
greater_than_4 = df[df["rating"] < 4]

# Find the top 5 most frequent places
top_5_places = greater_than_4["places"].value_counts().nlargest(5).index

# Filter the DataFrame to only include rows with the top 5 places
top_5_places_df = greater_than_4[greater_than_4["places"].isin(top_5_places)]

# Plot: Count of Places with Different Days (Days as hue)
sns.countplot(data=top_5_places_df, x="days", hue="places")
plt.title("Count of Places with Different Days (Rating >= 4)")
plt.xticks(rotation=45)
plt.show()
